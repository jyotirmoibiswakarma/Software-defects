# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotirmoibiswakarma/Software-defects/blob/main/Dissertation_Sem3_Result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')



from google.colab import drive
drive.mount('/content/drive',force_remount=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##**Importing Result**
# ####**Linking result of different methods applied**
# <table>
# <tr><th>Abbrevation</th><th>Slide Name</th></tr>
# <tr><td>d</td><td> Dissertation</td>
# <tr><td>dst</td><td> Dissertation_StratifiedTrain</tr>
# <tr><td>ds</td><td>DissertationSMOTE</td></tr>
# <tr><td>dv</td><td> Dissertation_Validation</td>
# <tr><td>dsd</td><td>Dissertation_Stratified</td></tr>
# <tr><td>dsv</td><td>DissertationSMOTE_Validation</td></tr>
# <tr><td>dss</td><td> Dissertation_ShuffleSplit</td></tr>

# %%
d=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/Dissertation.xlsx")
dst=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/Dissertation_StratifiedTrain.xlsx")
ds=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/DissertationSMOTE.xlsx")
dv=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/Dissertation_Validation.xlsx")
dsd=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/Dissertation_Stratified.xlsx")
dsv=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/DissertationSMOTE_Validation.xlsx")
dss=pd.read_excel("/content/drive/MyDrive/Dissertation_Phase_1_Final/Dissertation_ShuffleSplit.xlsx")

# %% [markdown]
# ##**Importing Datasets**

# %%
kc2_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/softwareDefect.csv")
jm1_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/jm1.csv")
ar1_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/ar1.csv")
ar3_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/ar3.csv")
ar4_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/ar4.csv")
ar5_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/ar5.csv")
ar6_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/ar6.csv")
kc1_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/kc1.csv")
cm1_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/cm1.csv")
pc1_df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/Dissertation/pc1.csv")

# %% [markdown]
# ##**Assigning Header to each column**

# %%
# adding column name to the respective columns
kc2_df.columns =['l_count', 'cyclomatic_complexity', 'essential_complexity', 'design_complexity','n','v','l','d','i','e','b','t','lOCode','lOComment','lOBlank','lOCodeAndComment','uniq_Op','uniq_Opnd','total_Op','total_Opnd','branchCount','problems']
kc1_df.columns =['l_count', 'cyclomatic_complexity', 'essential_complexity', 'design_complexity','n','v','l','d','i','e','b','t','lOCode','lOComment','lOBlank','lOCodeAndComment','uniq_Op','uniq_Opnd','total_Op','total_Opnd','branchCount','problems']
cm1_df.columns =['l_count', 'cyclomatic_complexity', 'essential_complexity', 'design_complexity','n','v','l','d','i','e','b','t','lOCode','lOComment','lOBlank','lOCodeAndComment','uniq_Op','uniq_Opnd','total_Op','total_Opnd','branchCount','problems']
pc1_df.columns =['l_count', 'cyclomatic_complexity', 'essential_complexity', 'design_complexity','n','v','l','d','i','e','b','t','lOCode','lOComment','lOBlank','lOCodeAndComment','uniq_Op','uniq_Opnd','total_Op','total_Opnd','branchCount','problems']
jm1_df.columns =['l_count', 'cyclomatic_complexity', 'essential_complexity', 'design_complexity','n','v','l','d','i','e','b','t','lOCode','lOComment','lOBlank','lOCodeAndComment','uniq_Op','uniq_Opnd','total_Op','total_Opnd','branchCount','problems']
ar1_df.columns=['total_loc','blank_loc','comment_loc','code_and_comment_loc','executable_loc','unique_operands','unique_operators','total_operands','total_operators','halstead_vocabulary','halstead_length','halstead_volume','halstead_level','halstead_difficulty','halstead_effort','halstead_error','halstead_time','branch_count','decision_count','call_pairs','condition_count','multiple_condition_count','cyclomatic_complexity','cyclomatic_density','decision_density','design_complexity','design_density','normalized_cyclomatic_complexity','formal_parameters','problems']
ar3_df.columns=['total_loc','blank_loc','comment_loc','code_and_comment_loc','executable_loc','unique_operands','unique_operators','total_operands','total_operators','halstead_vocabulary','halstead_length','halstead_volume','halstead_level','halstead_difficulty','halstead_effort','halstead_error','halstead_time','branch_count','decision_count','call_pairs','condition_count','multiple_condition_count','cyclomatic_complexity','cyclomatic_density','decision_density','design_complexity','design_density','normalized_cyclomatic_complexity','formal_parameters','problems']
ar4_df.columns=['total_loc','blank_loc','comment_loc','code_and_comment_loc','executable_loc','unique_operands','unique_operators','total_operands','total_operators','halstead_vocabulary','halstead_length','halstead_volume','halstead_level','halstead_difficulty','halstead_effort','halstead_error','halstead_time','branch_count','decision_count','call_pairs','condition_count','multiple_condition_count','cyclomatic_complexity','cyclomatic_density','decision_density','design_complexity','design_density','normalized_cyclomatic_complexity','formal_parameters','problems']
ar5_df.columns=['total_loc','blank_loc','comment_loc','code_and_comment_loc','executable_loc','unique_operands','unique_operators','total_operands','total_operators','halstead_vocabulary','halstead_length','halstead_volume','halstead_level','halstead_difficulty','halstead_effort','halstead_error','halstead_time','branch_count','decision_count','call_pairs','condition_count','multiple_condition_count','cyclomatic_complexity','cyclomatic_density','decision_density','design_complexity','design_density','normalized_cyclomatic_complexity','formal_parameters','problems']
ar6_df.columns=['total_loc','blank_loc','comment_loc','code_and_comment_loc','executable_loc','unique_operands','unique_operators','total_operands','total_operators','halstead_vocabulary','halstead_length','halstead_volume','halstead_level','halstead_difficulty','halstead_effort','halstead_error','halstead_time','branch_count','decision_count','call_pairs','condition_count','multiple_condition_count','cyclomatic_complexity','cyclomatic_density','decision_density','design_complexity','design_density','normalized_cyclomatic_complexity','formal_parameters','problems']

# %%
jm1_df.drop(jm1_df.loc[jm1_df['uniq_Op']=="?"].index, inplace=True)
kc2_df['problems'] = kc2_df['problems'].map({'yes':True ,'no':False})

# %% [markdown]
# ##**Table Content**
# Column Denotes Algorithm Name and there respective k-Values in case of validation Algorithm.
# <table>
# <tr><th>Abbrevation</th><th>Full Form</th></tr>
# <tr><td>lr</td><td>Logistic Regression</td></tr>
# <tr><td>svm</td><td>Support Vector Machine</td></tr>
# <tr><td>dt</td><td>Decision Tree</td></tr>
# <tr><td>re/rf</td><td>Random Forest</td></tr>
# <tr><td>b</td><td>Bagging</td></tr>
# </table>
#
# **lr2:** Logistic Regression having k=2.

# %% [markdown]
# ##**Applying Algorithm Direct to the dataset**

# %%
d
# Out:
#   Unnamed: 0       kc2       kc1   cm1       pc1       jm1       ar1  \
# 0         lr  0.828571  0.848341  0.93  0.923423  0.814338  0.875000
# 1        svm  0.895238  0.845972  0.93  0.932432  0.815717  0.875000
# 2         dt  0.809524  0.838863  0.88  0.936937  0.760110  0.875000
# 3         re  0.790476  0.855450  0.92  0.932432  0.760110  0.875000
# 4          b  0.838095  0.817536  0.89  0.923423  0.755515  0.833333
#
#         ar3       ar4       ar5   ar6
# 0  0.846154  0.909091  1.000000  0.85
# 1  0.923077  0.863636  0.714286  0.85
# 2  0.923077  0.818182  0.714286  0.75
# 3  0.923077  0.818182  0.714286  0.80
# 4  0.923077  0.772727  0.857143  0.70

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))

sns.scatterplot(d.iloc[:,0],d.kc2,s=100,label="kc2");
plt.plot(d.iloc[:,0],d.kc2);

sns.scatterplot(d.iloc[:,0],d.kc1,s=100,label="kc1");
plt.plot(d.iloc[:,0],d.kc1);

sns.scatterplot(d.iloc[:,0],d.cm1,s=100,label="cm1");
plt.plot(d.iloc[:,0],d.cm1);

sns.scatterplot(d.iloc[:,0],d.pc1,s=100,label="pc1");
plt.plot(d.iloc[:,0],d.pc1);

sns.scatterplot(d.iloc[:,0],d.jm1,s=100,label="jm1");
plt.plot(d.iloc[:,0],d.jm1);

sns.scatterplot(d.iloc[:,0],d.ar1,s=100,label="ar1");
plt.plot(d.iloc[:,0],d.ar1);

sns.scatterplot(d.iloc[:,0],d.ar3,s=100,label="ar3");
plt.plot(d.iloc[:,0],d.ar3);

sns.scatterplot(d.iloc[:,0],d.ar4,s=100,label="ar4");
plt.plot(d.iloc[:,0],d.ar4);

sns.scatterplot(d.iloc[:,0],d.ar5,s=100,label="ar5");
plt.plot(d.iloc[:,0],d.ar5);

sns.scatterplot(d.iloc[:,0],d.ar6,s=100,label="ar6");
plt.plot(d.iloc[:,0],d.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ##**Stratified training and validation data**

# %%
dst
# Out:
#   Unnamed: 0       kc2       kc1   cm1       pc1       jm1       ar1  \
# 0         lr  0.790476  0.860190  0.90  0.927928  0.809283  0.958333
# 1        svm  0.809524  0.855450  0.90  0.945946  0.811121  0.916667
# 2         dt  0.790476  0.800948  0.77  0.918919  0.752298  0.916667
# 3         rf  0.819048  0.857820  0.90  0.945946  0.804688  0.916667
# 4          b  0.733333  0.805687  0.80  0.909910  0.758272  0.833333
#
#         ar3       ar4       ar5   ar6
# 0  0.923077  0.909091  0.857143  0.85
# 1  0.923077  0.863636  1.000000  0.85
# 2  0.923077  0.863636  0.857143  0.70
# 3  1.000000  0.863636  0.714286  0.85
# 4  1.000000  0.909091  0.857143  0.80

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))

sns.scatterplot(dst.iloc[:,0],dst.kc2,s=100,label="kc2");
plt.plot(dst.iloc[:,0],dst.kc2);

sns.scatterplot(dst.iloc[:,0],dst.kc1,s=100,label="kc1");
plt.plot(dst.iloc[:,0],dst.kc1);

sns.scatterplot(dst.iloc[:,0],dst.cm1,s=100,label="cm1");
plt.plot(dst.iloc[:,0],dst.cm1);

sns.scatterplot(dst.iloc[:,0],dst.pc1,s=100,label="pc1");
plt.plot(dst.iloc[:,0],dst.pc1);

sns.scatterplot(dst.iloc[:,0],dst.jm1,s=100,label="jm1");
plt.plot(dst.iloc[:,0],dst.jm1);

sns.scatterplot(dst.iloc[:,0],dst.ar1,s=100,label="ar1");
plt.plot(dst.iloc[:,0],dst.ar1);

sns.scatterplot(dst.iloc[:,0],dst.ar3,s=100,label="ar3");
plt.plot(dst.iloc[:,0],dst.ar3);

sns.scatterplot(dst.iloc[:,0],dst.ar4,s=100,label="ar4");
plt.plot(dst.iloc[:,0],dst.ar4);

sns.scatterplot(dst.iloc[:,0],dst.ar5,s=100,label="ar5");
plt.plot(dst.iloc[:,0],dst.ar5);

sns.scatterplot(dst.iloc[:,0],dst.ar6,s=100,label="ar6");
plt.plot(dst.iloc[:,0],dst.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left');
plt.tight_layout();
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
ds
# Out:
#   Unnamed: 0       kc2       kc1   cm1       pc1       jm1       ar1  \
# 0         lr  0.752381  0.772512  0.86  0.828829  0.714154  0.750000
# 1        svm  0.771429  0.789100  0.86  0.770270  0.762868  0.708333
# 2         dt  0.857143  0.829384  0.85  0.887387  0.719210  0.875000
# 3         re  0.857143  0.808057  0.86  0.932432  0.763787  0.916667
# 4          b  0.838095  0.819905  0.81  0.860360  0.711857  0.875000
#
#         ar3       ar4       ar5   ar6
# 0  0.769231  0.727273  1.000000  0.75
# 1  0.769231  0.772727  0.857143  0.80
# 2  0.846154  0.818182  0.714286  0.75
# 3  0.846154  0.818182  1.000000  0.85
# 4  0.923077  0.818182  0.714286  0.65

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))

sns.scatterplot(ds.iloc[:,0],ds.kc2,s=100,label="kc2");
plt.plot(ds.iloc[:,0],ds.kc2);

sns.scatterplot(ds.iloc[:,0],ds.kc1,s=100,label="kc1");
plt.plot(ds.iloc[:,0],ds.kc1);

sns.scatterplot(ds.iloc[:,0],ds.cm1,s=100,label="cm1");
plt.plot(ds.iloc[:,0],ds.cm1);

sns.scatterplot(ds.iloc[:,0],ds.pc1,s=100,label="pc1");
plt.plot(ds.iloc[:,0],ds.pc1);

sns.scatterplot(ds.iloc[:,0],ds.jm1,s=100,label="jm1");
plt.plot(ds.iloc[:,0],ds.jm1);

sns.scatterplot(ds.iloc[:,0],ds.ar1,s=100,label="ar1");
plt.plot(ds.iloc[:,0],ds.ar1);

sns.scatterplot(ds.iloc[:,0],ds.ar3,s=100,label="ar3");
plt.plot(ds.iloc[:,0],ds.ar3);

sns.scatterplot(ds.iloc[:,0],ds.ar4,s=100,label="ar4");
plt.plot(ds.iloc[:,0],ds.ar4);

sns.scatterplot(ds.iloc[:,0],ds.ar5,s=100,label="ar5");
plt.plot(ds.iloc[:,0],ds.ar5);

sns.scatterplot(ds.iloc[:,0],ds.ar6,s=100,label="ar6");
plt.plot(ds.iloc[:,0],ds.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left');
plt.tight_layout();
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dv
# Out:
#    Unnamed: 0       kc2       kc1       cm1       pc1       jm1       ar1  \
# 0         lr2  0.823438  0.851992  0.879283  0.926895  0.777740  0.900000
# 1         lr3  0.825372  0.842508  0.889388  0.932313  0.772494  0.891667
# 2         lr4  0.823532  0.843928  0.887339  0.930505  0.786379  0.916667
# 3         lr5  0.827381  0.850568  0.885374  0.930545  0.764683  0.900000
# 4         lr6  0.823398  0.843463  0.889387  0.931434  0.782055  0.908333
# 5         lr7  0.829318  0.849621  0.893360  0.930522  0.778103  0.891690
# 6         lr8  0.829341  0.846305  0.885241  0.925125  0.771945  0.900000
# 7         lr9  0.819554  0.849152  0.883297  0.933226  0.771024  0.891331
# 8        lr10  0.831205  0.845823  0.885469  0.931409  0.801269  0.900000
# 9        svm2  0.825339  0.845351  0.901428  0.928700  0.808530  0.916667
# 10       svm3  0.836888  0.850098  0.901460  0.930509  0.808254  0.916667
# 11       svm4  0.827290  0.851044  0.901452  0.930505  0.808255  0.916667
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(24,8))

sns.scatterplot(dv.iloc[:,0],dv.kc2,s=100,label="kc2");
plt.plot(dv.iloc[:,0],dv.kc2);

sns.scatterplot(dv.iloc[:,0],dv.kc1,s=100,label="kc1");
plt.plot(dv.iloc[:,0],dv.kc1);

sns.scatterplot(dv.iloc[:,0],dv.cm1,s=100,label="cm1");
plt.plot(dv.iloc[:,0],dv.cm1);

sns.scatterplot(dv.iloc[:,0],dv.pc1,s=100,label="pc1");
plt.plot(dv.iloc[:,0],dv.pc1);

sns.scatterplot(dv.iloc[:,0],dv.jm1,s=100,label="jm1");
plt.plot(dv.iloc[:,0],dv.jm1);

sns.scatterplot(dv.iloc[:,0],dv.ar1,s=100,label="ar1");
plt.plot(dv.iloc[:,0],dv.ar1);

sns.scatterplot(dv.iloc[:,0],dv.ar3,s=100,label="ar3");
plt.plot(dv.iloc[:,0],dv.ar3);

sns.scatterplot(dv.iloc[:,0],dv.ar4,s=100,label="ar4");
plt.plot(dv.iloc[:,0],dv.ar4);

sns.scatterplot(dv.iloc[:,0],dv.ar5,s=100,label="ar5");
plt.plot(dv.iloc[:,0],dv.ar5);

sns.scatterplot(dv.iloc[:,0],dv.ar6,s=100,label="ar6");
plt.plot(dv.iloc[:,0],dv.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dsd
# Out:
#    Unnamed: 0       kc2       kc1       cm1       pc1       jm1       ar1  \
# 0         lr2  0.790760  0.853416  0.883283  0.913357  0.764045  0.816667
# 1         lr3  0.813678  0.843462  0.885311  0.925999  0.766714  0.816667
# 2         lr4  0.823326  0.844877  0.881290  0.925090  0.759726  0.841667
# 3         lr5  0.830879  0.844414  0.885374  0.925095  0.770204  0.858333
# 4         lr6  0.809743  0.843929  0.883314  0.930508  0.792811  0.850000
# 5         lr7  0.815470  0.846293  0.883300  0.929584  0.751908  0.866013
# 6         lr8  0.817424  0.841089  0.885369  0.932306  0.775261  0.841667
# 7         lr9  0.821402  0.845348  0.885354  0.933204  0.761571  0.890720
# 8        lr10  0.819340  0.844902  0.891388  0.928714  0.764783  0.850000
# 9        svm2  0.809962  0.850095  0.901412  0.930505  0.805773  0.925000
# 10       svm3  0.821374  0.841085  0.901412  0.930506  0.805865  0.925000
# 11       svm4  0.828993  0.846300  0.901419  0.930505  0.806508  0.925000
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(24,8))

sns.scatterplot(dsd.iloc[:,0],dsd.kc2,s=100,label="kc2");
plt.plot(dsd.iloc[:,0],dsd.kc2);

sns.scatterplot(dsd.iloc[:,0],dsd.kc1,s=100,label="kc1");
plt.plot(dsd.iloc[:,0],dsd.kc1);

sns.scatterplot(dsd.iloc[:,0],dsd.cm1,s=100,label="cm1");
plt.plot(dsd.iloc[:,0],dsd.cm1);

sns.scatterplot(dsd.iloc[:,0],dsd.pc1,s=100,label="pc1");
plt.plot(dsd.iloc[:,0],dsd.pc1);

sns.scatterplot(dsd.iloc[:,0],dsd.jm1,s=100,label="jm1");
plt.plot(dsd.iloc[:,0],dsd.jm1);

sns.scatterplot(dsd.iloc[:,0],dsd.ar1,s=100,label="ar1");
plt.plot(dsd.iloc[:,0],dsd.ar1);

sns.scatterplot(dsd.iloc[:,0],dsd.ar3,s=100,label="ar3");
plt.plot(dsd.iloc[:,0],dsd.ar3);

sns.scatterplot(dsd.iloc[:,0],dsd.ar4,s=100,label="ar4");
plt.plot(dsd.iloc[:,0],dsd.ar4);

sns.scatterplot(dsd.iloc[:,0],dsd.ar5,s=100,label="ar5");
plt.plot(dsd.iloc[:,0],dsd.ar5);

sns.scatterplot(dsd.iloc[:,0],dsd.ar6,s=100,label="ar6");
plt.plot(dsd.iloc[:,0],dsd.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left');
plt.tight_layout();
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dsv
# Out:
#    Unnamed: 0       kc2       kc1       cm1       pc1       jm1       ar1  \
# 0         lr2  0.823438  0.849146  0.879283  0.926895  0.777740  0.900000
# 1         lr3  0.827287  0.846306  0.889388  0.932313  0.772494  0.891667
# 2         lr4  0.823547  0.843928  0.887339  0.930505  0.786379  0.916667
# 3         lr5  0.827381  0.850568  0.885374  0.930545  0.764683  0.900000
# 4         lr6  0.821483  0.843938  0.889387  0.931434  0.782055  0.908333
# 5         lr7  0.833127  0.849620  0.893360  0.930522  0.778103  0.891690
# 6         lr8  0.831265  0.846775  0.885241  0.925125  0.771945  0.900000
# 7         lr9  0.819554  0.846788  0.883297  0.933226  0.771024  0.891331
# 8        lr10  0.831205  0.848192  0.885469  0.931409  0.801269  0.900000
# 9        svm2  0.825339  0.845351  0.901428  0.928700  0.808530  0.916667
# 10       svm3  0.836888  0.850098  0.901460  0.930509  0.808254  0.916667
# 11       svm4  0.827290  0.851044  0.901452  0.930505  0.808255  0.916667
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(24,8))

sns.scatterplot(dsv.iloc[:,0],dsv.kc2,s=100,label="kc2");
plt.plot(dsv.iloc[:,0],dsv.kc2);

sns.scatterplot(dsv.iloc[:,0],dsv.kc1,s=100,label="kc1");
plt.plot(dsv.iloc[:,0],dsv.kc1);

sns.scatterplot(dsv.iloc[:,0],dsv.cm1,s=100,label="cm1");
plt.plot(dsv.iloc[:,0],dsv.cm1);

sns.scatterplot(dsv.iloc[:,0],dsv.pc1,s=100,label="pc1");
plt.plot(dsv.iloc[:,0],dsv.pc1);

sns.scatterplot(dsv.iloc[:,0],dsv.jm1,s=100,label="jm1");
plt.plot(dsv.iloc[:,0],dsv.jm1);

sns.scatterplot(dsv.iloc[:,0],dsv.ar1,s=100,label="ar1");
plt.plot(dsv.iloc[:,0],dsv.ar1);

sns.scatterplot(dsv.iloc[:,0],dsv.ar3,s=100,label="ar3");
plt.plot(dsv.iloc[:,0],dsv.ar3);

sns.scatterplot(dsv.iloc[:,0],dsv.ar4,s=100,label="ar4");
plt.plot(dsv.iloc[:,0],dsv.ar4);

sns.scatterplot(dsv.iloc[:,0],dsv.ar5,s=100,label="ar5");
plt.plot(dsv.iloc[:,0],dsv.ar5);

sns.scatterplot(dsv.iloc[:,0],dsv.ar6,s=100,label="ar6");
plt.plot(dsv.iloc[:,0],dsv.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left');
plt.tight_layout();
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dss
# Out:
#    Unnamed: 0       kc2       kc1       cm1       pc1       jm1       ar1  \
# 0         lr2  0.843949  0.842022  0.903333  0.926426  0.748468  0.861111
# 1         lr3  0.828025  0.833070  0.891111  0.926927  0.765625  0.842593
# 2         lr4  0.842357  0.838863  0.908333  0.921922  0.762638  0.840278
# 3         lr5  0.828025  0.853397  0.890667  0.929129  0.792034  0.811111
# 4         lr6  0.830149  0.853344  0.874444  0.930430  0.789624  0.851852
# 5         lr7  0.816197  0.842699  0.885714  0.933934  0.773766  0.876984
# 6         lr8  0.814490  0.844984  0.883333  0.923423  0.798790  0.878472
# 7         lr9  0.816702  0.845006  0.885926  0.936937  0.788569  0.882716
# 8        lr10  0.845223  0.848025  0.891333  0.929730  0.792862  0.897222
# 9        svm2  0.828025  0.850711  0.913333  0.933934  0.807138  0.888889
# 10       svm3  0.838641  0.852027  0.906667  0.929930  0.808313  0.944444
# 11       svm4  0.812102  0.861769  0.923333  0.927928  0.809589  0.909722
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(24,8))

sns.scatterplot(dss.iloc[:,0],dss.kc2,s=100,label="kc2");
plt.plot(dss.iloc[:,0],dss.kc2);

sns.scatterplot(dss.iloc[:,0],dss.kc1,s=100,label="kc1");
plt.plot(dss.iloc[:,0],dss.kc1);

sns.scatterplot(dss.iloc[:,0],dss.cm1,s=100,label="cm1");
plt.plot(dss.iloc[:,0],dss.cm1);

sns.scatterplot(dss.iloc[:,0],dss.pc1,s=100,label="pc1");
plt.plot(dss.iloc[:,0],dss.pc1);

sns.scatterplot(dss.iloc[:,0],dss.jm1,s=100,label="jm1");
plt.plot(dss.iloc[:,0],dss.jm1);

sns.scatterplot(dss.iloc[:,0],dss.ar1,s=100,label="ar1");
plt.plot(dss.iloc[:,0],dss.ar1);

sns.scatterplot(dss.iloc[:,0],dss.ar3,s=100,label="ar3");
plt.plot(dss.iloc[:,0],dss.ar3);

sns.scatterplot(dss.iloc[:,0],dss.ar4,s=100,label="ar4");
plt.plot(dss.iloc[:,0],dss.ar4);

sns.scatterplot(dss.iloc[:,0],dss.ar5,s=100,label="ar5");
plt.plot(dss.iloc[:,0],dss.ar5);

sns.scatterplot(dss.iloc[:,0],dss.ar6,s=100,label="ar6");
plt.plot(dss.iloc[:,0],dss.ar6);

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left');
plt.tight_layout();
plt.show();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
